# %%
import torch
from denoising_diffusion_pytorch import Unet, GaussianDiffusion

model = Unet(
    dim = 64,
    dim_mults = (1, 2, 4, 8)
)

diffusion = GaussianDiffusion(
    model,
    image_size = 128,
    timesteps = 1000    # number of steps
)

training_images = torch.rand(8, 3, 128, 128) # images are normalized from 0 to 1
loss = diffusion(training_images)
loss.backward()
# after a lot of training

sampled_images = diffusion.sample(batch_size = 4)
sampled_images.shape # (4, 3, 128, 128)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#       9 diffusion = GaussianDiffusion(
#      10     model,
#      11     image_size = 128,
#      12     timesteps = 1000    # number of steps
#      13 )
#      15 training_images = torch.rand(8, 3, 128, 128) # images are normalized from 0 to 1
# ---> 16 loss = diffusion(training_images)
#      17 loss.backward()
#      18 # after a lot of training
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\CloudServices\Dropbox\Dropbox\2023-1-lastchance\pgm\prj\pretrain\denoising_diffusion_pytorch\denoising_diffusion_pytorch.py:799, in GaussianDiffusion.forward(self, img, *args, **kwargs)
#     796 img = self.normalize(img)
#     797 #####
# --> 799 return self.p_losses(img, t, *args, **kwargs)
#
# File D:\CloudServices\Dropbox\Dropbox\2023-1-lastchance\pgm\prj\pretrain\denoising_diffusion_pytorch\denoising_diffusion_pytorch.py:760, in GaussianDiffusion.p_losses(self, x_start, t, noise)
#     756         x_self_cond.detach_()
#     758 # predict and take gradient step
# --> 760 model_out = self.model(x, t, x_self_cond)
#     762 if self.objective == 'pred_noise':
#     763     target = noise
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\CloudServices\Dropbox\Dropbox\2023-1-lastchance\pgm\prj\pretrain\denoising_diffusion_pytorch\denoising_diffusion_pytorch.py:395, in Unet.forward(self, x, time, x_self_cond)
#     393     x = torch.cat((x, h.pop()), dim = 1)
#     394     x = block2(x, t)
# --> 395     x = attn(x)
#     397     x = upsample(x)
#     399 x = torch.cat((x, r), dim = 1)
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\CloudServices\Dropbox\Dropbox\2023-1-lastchance\pgm\prj\pretrain\denoising_diffusion_pytorch\denoising_diffusion_pytorch.py:90, in Residual.forward(self, x, *args, **kwargs)
#      89 def forward(self, x, *args, **kwargs):
# ---> 90     return self.fn(x, *args, **kwargs) + x
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\CloudServices\Dropbox\Dropbox\2023-1-lastchance\pgm\prj\pretrain\denoising_diffusion_pytorch\denoising_diffusion_pytorch.py:138, in PreNorm.forward(self, x)
#     136 def forward(self, x):
#     137     x = self.norm(x)
# --> 138     return self.fn(x)
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File D:\CloudServices\Dropbox\Dropbox\2023-1-lastchance\pgm\prj\pretrain\denoising_diffusion_pytorch\denoising_diffusion_pytorch.py:247, in LinearAttention.forward(self, x)
#     245 out = torch.einsum('b h d e, b h d n -> b h e n', context, q)
#     246 out = rearrange(out, 'b h c (x y) -> b (h c) x y', h = self.heads, x = h, y = w)
# --> 247 return self.to_out(out)
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File d:\cloudservices\dropbox\dropbox\2023-1-lastchance\pgm\prj\pretrain\venv\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
